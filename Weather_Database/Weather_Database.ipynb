# %%
# Import dependencies
import pandas as pd
import numpy as np
import json
import requests
import timeit
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | bella vista
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | goderich
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | san carlos de bariloche
# Processing Record 8 of Set 1 | sapa
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | diffa
# Processing Record 14 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 1 | hovd
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | sinnamary
# Processing Record 20 of Set 1 | koslan
# Processing Record 21 of Set 1 | roald
# Processing Record 22 of Set 1 | uri
# Processing Record 23 of Set 1 | charters towers
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | kapoeta
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | hirara
# Processing Record 32 of Set 1 | sao felix do xingu
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | nhulunbuy
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | mehamn
# Processing Record 41 of Set 1 | lavrentiya
# Processing Record 42 of Set 1 | manaure
# Processing Record 43 of Set 1 | nizwa
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | ambilobe
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | port-gentil
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | orbetello
# Processing Record 1 of Set 2 | lagoa
# Processing Record 2 of Set 2 | kalmunai
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | hobyo
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | fairbanks
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | christchurch
# Processing Record 10 of Set 2 | alugan
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 2 | matara
# Processing Record 14 of Set 2 | calvinia
# Processing Record 15 of Set 2 | ketchikan
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | west odessa
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | vanimo
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | tubuala
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | sosva
# Processing Record 28 of Set 2 | manavalakurichi
# Processing Record 29 of Set 2 | rimbey
# Processing Record 30 of Set 2 | timizart
# Processing Record 31 of Set 2 | pucara
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | northam
# Processing Record 37 of Set 2 | teahupoo
# Processing Record 38 of Set 2 | gallup
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | nantucket
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | la ronge
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | naze
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | abu samrah
# Processing Record 6 of Set 3 | kralendijk
# Processing Record 7 of Set 3 | berlevag
# Processing Record 8 of Set 3 | inongo
# Processing Record 9 of Set 3 | shimoda
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | fomboni
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | sampit
# Processing Record 19 of Set 3 | inhambane
# Processing Record 20 of Set 3 | omboue
# Processing Record 21 of Set 3 | zhigansk
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | ust-tsilma
# Processing Record 26 of Set 3 | burnie
# Processing Record 27 of Set 3 | paamiut
# Processing Record 28 of Set 3 | kapit
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | montgomery
# Processing Record 31 of Set 3 | itaituba
# Processing Record 32 of Set 3 | portland
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | el faiyum
# City not found. Skipping...
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | henties bay
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | fortuna
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | cape town
# Processing Record 46 of Set 3 | maceio
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | general pico
# Processing Record 49 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 3 | disna
# Processing Record 1 of Set 4 | varhaug
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | homer
# Processing Record 4 of Set 4 | marsabit
# Processing Record 5 of Set 4 | challapata
# Processing Record 6 of Set 4 | ahipara
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | shetpe
# Processing Record 9 of Set 4 | san juan
# Processing Record 10 of Set 4 | bharatpur
# Processing Record 11 of Set 4 | san jose
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | tulum
# Processing Record 14 of Set 4 | bengkulu
# Processing Record 15 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | ulaanbaatar
# Processing Record 17 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | arman
# Processing Record 20 of Set 4 | asyut
# Processing Record 21 of Set 4 | rorvik
# Processing Record 22 of Set 4 | castro
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | killybegs
# Processing Record 27 of Set 4 | constitucion
# Processing Record 28 of Set 4 | santa fe
# Processing Record 29 of Set 4 | rosendal
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | helong
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | egvekinot
# Processing Record 34 of Set 4 | kulzeb
# City not found. Skipping...
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | amarwara
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | amga
# Processing Record 40 of Set 4 | la primavera
# Processing Record 41 of Set 4 | new norfolk
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | ilebo
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | opuwo
# Processing Record 46 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 47 of Set 4 | sapao
# City not found. Skipping...
# Processing Record 48 of Set 4 | tarata
# Processing Record 49 of Set 4 | laguna
# Processing Record 50 of Set 4 | naryan-mar
# Processing Record 1 of Set 5 | dunedin
# Processing Record 2 of Set 5 | strezhevoy
# Processing Record 3 of Set 5 | san quintin
# Processing Record 4 of Set 5 | bay roberts
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | karwar
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | saint-joseph
# Processing Record 9 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 5 | turbat
# Processing Record 11 of Set 5 | stromness
# Processing Record 12 of Set 5 | paoua
# Processing Record 13 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 5 | corn island
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | vostok
# Processing Record 17 of Set 5 | lasa
# Processing Record 18 of Set 5 | chifeng
# Processing Record 19 of Set 5 | lagos
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | sinop
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | bolshoye murashkino
# Processing Record 24 of Set 5 | thompson
# Processing Record 25 of Set 5 | mandera
# Processing Record 26 of Set 5 | ati
# Processing Record 27 of Set 5 | san rafael
# Processing Record 28 of Set 5 | kitchener
# Processing Record 29 of Set 5 | lazaro cardenas
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 5 | andenes
# Processing Record 33 of Set 5 | bondoukou
# Processing Record 34 of Set 5 | empalme
# Processing Record 35 of Set 5 | karratha
# Processing Record 36 of Set 5 | aragarcas
# Processing Record 37 of Set 5 | singaraja
# Processing Record 38 of Set 5 | diego de almagro
# Processing Record 39 of Set 5 | linden
# Processing Record 40 of Set 5 | coos bay
# Processing Record 41 of Set 5 | bankja
# City not found. Skipping...
# Processing Record 42 of Set 5 | louis trichardt
# Processing Record 43 of Set 5 | poum
# Processing Record 44 of Set 5 | pemangkat
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 5 | albert lea
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | voitsberg
# Processing Record 50 of Set 5 | adelaide
# Processing Record 1 of Set 6 | elko
# Processing Record 2 of Set 6 | yerbogachen
# Processing Record 3 of Set 6 | hambantota
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | zorya
# Processing Record 7 of Set 6 | mao
# Processing Record 8 of Set 6 | lillooet
# Processing Record 9 of Set 6 | peniche
# Processing Record 10 of Set 6 | dhidhdhoo
# Processing Record 11 of Set 6 | cabatuan
# Processing Record 12 of Set 6 | saint george
# Processing Record 13 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 6 | kristiinankaupunki
# Processing Record 15 of Set 6 | sanlucar la mayor
# Processing Record 16 of Set 6 | suksun
# Processing Record 17 of Set 6 | port augusta
# Processing Record 18 of Set 6 | ushtobe
# Processing Record 19 of Set 6 | iralaya
# Processing Record 20 of Set 6 | pangnirtung
# Processing Record 21 of Set 6 | komsomolskiy
# Processing Record 22 of Set 6 | kolvereid
# Processing Record 23 of Set 6 | ogaminana
# Processing Record 24 of Set 6 | kaoma
# Processing Record 25 of Set 6 | corrales
# Processing Record 26 of Set 6 | udachnyy
# Processing Record 27 of Set 6 | namibe
# Processing Record 28 of Set 6 | cape canaveral
# Processing Record 29 of Set 6 | tela
# Processing Record 30 of Set 6 | mambajao
# Processing Record 31 of Set 6 | burica
# City not found. Skipping...
# Processing Record 32 of Set 6 | airai
# Processing Record 33 of Set 6 | keetmanshoop
# Processing Record 34 of Set 6 | durres
# Processing Record 35 of Set 6 | jalu
# Processing Record 36 of Set 6 | bereda
# Processing Record 37 of Set 6 | hualmay
# Processing Record 38 of Set 6 | portage
# Processing Record 39 of Set 6 | kilindoni
# Processing Record 40 of Set 6 | bogorodskoye
# Processing Record 41 of Set 6 | kamenka
# Processing Record 42 of Set 6 | albina
# Processing Record 43 of Set 6 | mitsamiouli
# Processing Record 44 of Set 6 | katete
# Processing Record 45 of Set 6 | matagami
# Processing Record 46 of Set 6 | chiredzi
# Processing Record 47 of Set 6 | riachao das neves
# Processing Record 48 of Set 6 | hohhot
# Processing Record 49 of Set 6 | chapais
# Processing Record 50 of Set 6 | anicuns
# Processing Record 1 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 7 | ginir
# Processing Record 3 of Set 7 | avanigadda
# Processing Record 4 of Set 7 | diu
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | salinopolis
# Processing Record 8 of Set 7 | erdenet
# Processing Record 9 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 10 of Set 7 | mucurapo
# Processing Record 11 of Set 7 | kenai
# Processing Record 12 of Set 7 | sitka
# Processing Record 13 of Set 7 | mahina
# Processing Record 14 of Set 7 | birin
# Processing Record 15 of Set 7 | port elizabeth
# Processing Record 16 of Set 7 | mayo
# Processing Record 17 of Set 7 | whitehorse
# Processing Record 18 of Set 7 | qunduz
# Processing Record 19 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 20 of Set 7 | claresholm
# Processing Record 21 of Set 7 | nara
# Processing Record 22 of Set 7 | yulara
# Processing Record 23 of Set 7 | damghan
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | kawalu
# Processing Record 26 of Set 7 | anan
# Processing Record 27 of Set 7 | waingapu
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | tura
# Processing Record 30 of Set 7 | san policarpo
# Processing Record 31 of Set 7 | baruun-urt
# Processing Record 32 of Set 7 | jumla
# Processing Record 33 of Set 7 | mizdah
# Processing Record 34 of Set 7 | fukue
# Processing Record 35 of Set 7 | sulangan
# Processing Record 36 of Set 7 | monte azul
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 7 | mbandaka
# Processing Record 40 of Set 7 | rafaela
# Processing Record 41 of Set 7 | aykhal
# Processing Record 42 of Set 7 | broken hill
# Processing Record 43 of Set 7 | darlowo
# Processing Record 44 of Set 7 | doha
# Processing Record 45 of Set 7 | acapulco
# Processing Record 46 of Set 7 | tessalit
# Processing Record 47 of Set 7 | lensk
# Processing Record 48 of Set 7 | souillac
# Processing Record 49 of Set 7 | kontagora
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | burns lake
# Processing Record 2 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 8 | rio verde de mato grosso
# Processing Record 4 of Set 8 | pandan
# Processing Record 5 of Set 8 | maragogi
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | akyab
# Processing Record 8 of Set 8 | leh
# Processing Record 9 of Set 8 | larsnes
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | lodwar
# Processing Record 12 of Set 8 | paracuru
# Processing Record 13 of Set 8 | barranca
# Processing Record 14 of Set 8 | baeza
# Processing Record 15 of Set 8 | comodoro rivadavia
# Processing Record 16 of Set 8 | westport
# Processing Record 17 of Set 8 | solnechnyy
# Processing Record 18 of Set 8 | aloleng
# Processing Record 19 of Set 8 | yumen
# Processing Record 20 of Set 8 | loikaw
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | pinawa
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | gamba
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | birnin kebbi
# Processing Record 27 of Set 8 | crotone
# Processing Record 28 of Set 8 | tongliao
# Processing Record 29 of Set 8 | mongo
# Processing Record 30 of Set 8 | taicheng
# Processing Record 31 of Set 8 | la asuncion
# Processing Record 32 of Set 8 | tautira
# Processing Record 33 of Set 8 | noyabrsk
# Processing Record 34 of Set 8 | norman wells
# Processing Record 35 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 36 of Set 8 | humaita
# Processing Record 37 of Set 8 | otavi
# Processing Record 38 of Set 8 | ponnani
# Processing Record 39 of Set 8 | gwadar
# Processing Record 40 of Set 8 | gazli
# Processing Record 41 of Set 8 | santa marta
# Processing Record 42 of Set 8 | nioro
# Processing Record 43 of Set 8 | montes claros
# Processing Record 44 of Set 8 | babushkin
# Processing Record 45 of Set 8 | sur
# Processing Record 46 of Set 8 | novyy urengoy
# Processing Record 47 of Set 8 | goiatuba
# Processing Record 48 of Set 8 | bud
# Processing Record 49 of Set 8 | christiana
# Processing Record 50 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 9 | sosenskiy
# Processing Record 2 of Set 9 | that phanom
# Processing Record 3 of Set 9 | maku
# Processing Record 4 of Set 9 | sarangani
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 9 | pingdu
# Processing Record 7 of Set 9 | balkanabat
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | maamba
# Processing Record 10 of Set 9 | praya
# Processing Record 11 of Set 9 | skala
# Processing Record 12 of Set 9 | brazzaville
# Processing Record 13 of Set 9 | santa maria
# Processing Record 14 of Set 9 | keflavik
# Processing Record 15 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 9 | nanortalik
# Processing Record 17 of Set 9 | deputatskiy
# Processing Record 18 of Set 9 | margate
# Processing Record 19 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 9 | luderitz
# Processing Record 21 of Set 9 | horta
# Processing Record 22 of Set 9 | ostersund
# Processing Record 23 of Set 9 | malia
# Processing Record 24 of Set 9 | victoria
# Processing Record 25 of Set 9 | katobu
# Processing Record 26 of Set 9 | yarmouth
# Processing Record 27 of Set 9 | pozoblanco
# Processing Record 28 of Set 9 | aranos
# Processing Record 29 of Set 9 | palmer
# Processing Record 30 of Set 9 | floro
# Processing Record 31 of Set 9 | kirakira
# Processing Record 32 of Set 9 | ewo
# Processing Record 33 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 9 | ribeira brava
# Processing Record 35 of Set 9 | kurtalan
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 9 | karoi
# Processing Record 39 of Set 9 | hami
# Processing Record 40 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | santo antonio do taua
# Processing Record 43 of Set 9 | kano
# Processing Record 44 of Set 9 | tiarei
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | sobolevo
# Processing Record 47 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 9 | sassandra
# Processing Record 49 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 9 | fort nelson
# Processing Record 1 of Set 10 | plettenberg bay
# Processing Record 2 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 10 | lilongwe
# Processing Record 4 of Set 10 | beska
# Processing Record 5 of Set 10 | manaus
# Processing Record 6 of Set 10 | khandyga
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | carora
# Processing Record 9 of Set 10 | cap malheureux
# Processing Record 10 of Set 10 | namatanai
# Processing Record 11 of Set 10 | mora
# Processing Record 12 of Set 10 | pirapemas
# Processing Record 13 of Set 10 | great yarmouth
# Processing Record 14 of Set 10 | wamba
# Processing Record 15 of Set 10 | erenhot
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | fano
# Processing Record 18 of Set 10 | visnes
# Processing Record 19 of Set 10 | marzuq
# Processing Record 20 of Set 10 | buloh kasap
# Processing Record 21 of Set 10 | alice springs
# Processing Record 22 of Set 10 | severnyy
# Processing Record 23 of Set 10 | rio grande
# Processing Record 24 of Set 10 | craig
# Processing Record 25 of Set 10 | grand gaube
# Processing Record 26 of Set 10 | cape coast
# Processing Record 27 of Set 10 | touros
# Processing Record 28 of Set 10 | sudak
# Processing Record 29 of Set 10 | balikpapan
# Processing Record 30 of Set 10 | port blair
# Processing Record 31 of Set 10 | manakara
# Processing Record 32 of Set 10 | san andres
# Processing Record 33 of Set 10 | kungurtug
# Processing Record 34 of Set 10 | havoysund
# Processing Record 35 of Set 10 | sao caetano de odivelas
# Processing Record 36 of Set 10 | sumbawanga
# Processing Record 37 of Set 10 | khokhlovo
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | tarauaca
# Processing Record 40 of Set 10 | zhicheng
# Processing Record 41 of Set 10 | serenje
# Processing Record 42 of Set 10 | panaba
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | tezpur
# Processing Record 45 of Set 10 | balabac
# Processing Record 46 of Set 10 | breukelen
# Processing Record 47 of Set 10 | puerto ayacucho
# Processing Record 48 of Set 10 | srednekolymsk
# Processing Record 49 of Set 10 | shache
# Processing Record 50 of Set 10 | kostomuksha
# Processing Record 1 of Set 11 | nemuro
# Processing Record 2 of Set 11 | herat
# Processing Record 3 of Set 11 | roma
# Processing Record 4 of Set 11 | leningradskiy
# Processing Record 5 of Set 11 | bouna
# Processing Record 6 of Set 11 | mayari
# City not found. Skipping...
# Processing Record 7 of Set 11 | itoigawa
# Processing Record 8 of Set 11 | osmaniye
# Processing Record 9 of Set 11 | butembo
# Processing Record 10 of Set 11 | xichang
# Processing Record 11 of Set 11 | halifax
# Processing Record 12 of Set 11 | kropotkin
# Processing Record 13 of Set 11 | yeppoon
# Processing Record 14 of Set 11 | kalga
# Processing Record 15 of Set 11 | puerto del rosario
# Processing Record 16 of Set 11 | marystown
# Processing Record 17 of Set 11 | chernyshevskiy
# Processing Record 18 of Set 11 | ginda
# Processing Record 19 of Set 11 | gunjur
# Processing Record 20 of Set 11 | xining
# Processing Record 21 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 11 | buala
# Processing Record 23 of Set 11 | vrangel
# Processing Record 24 of Set 11 | nyurba
# Processing Record 25 of Set 11 | talnakh
# Processing Record 26 of Set 11 | richards bay
# Processing Record 27 of Set 11 | nieves
# Processing Record 28 of Set 11 | pisco
# Processing Record 29 of Set 11 | san antonio
# Processing Record 30 of Set 11 | grand island
# Processing Record 31 of Set 11 | manggar
# Processing Record 32 of Set 11 | martapura
# Processing Record 33 of Set 11 | ninghai
# Processing Record 34 of Set 11 | faya
# Processing Record 35 of Set 11 | abonnema
# Processing Record 36 of Set 11 | tambacounda
# Processing Record 37 of Set 11 | thurso
# Processing Record 38 of Set 11 | maxixe
# Processing Record 39 of Set 11 | utiel
# Processing Record 40 of Set 11 | melun
# Processing Record 41 of Set 11 | sao geraldo do araguaia
# Processing Record 42 of Set 11 | algeciras
# Processing Record 43 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 11 | camopi
# Processing Record 45 of Set 11 | sonoita
# Processing Record 46 of Set 11 | pocatello
# Processing Record 47 of Set 11 | chengde
# Processing Record 48 of Set 11 | tigil
# Processing Record 49 of Set 11 | verkhoyansk
# Processing Record 50 of Set 11 | sozimskiy
# Processing Record 1 of Set 12 | namalenga
# Processing Record 2 of Set 12 | bilibino
# Processing Record 3 of Set 12 | tateyama
# Processing Record 4 of Set 12 | metsovon
# City not found. Skipping...
# Processing Record 5 of Set 12 | la macarena
# Processing Record 6 of Set 12 | lappeenranta
# Processing Record 7 of Set 12 | soria
# Processing Record 8 of Set 12 | uddevalla
# Processing Record 9 of Set 12 | ilulissat
# Processing Record 10 of Set 12 | kaseda
# Processing Record 11 of Set 12 | korla
# Processing Record 12 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 12 | palafrugell
# Processing Record 14 of Set 12 | chapleau
# Processing Record 15 of Set 12 | medicine hat
# Processing Record 16 of Set 12 | pakwach
# City not found. Skipping...
# Processing Record 17 of Set 12 | bad sachsa
# Processing Record 18 of Set 12 | coolum beach
# Processing Record 19 of Set 12 | asau
# Processing Record 20 of Set 12 | evensk
# Processing Record 21 of Set 12 | darfield
# Processing Record 22 of Set 12 | sorland
# Processing Record 23 of Set 12 | mvangue
# Processing Record 24 of Set 12 | constantine
# Processing Record 25 of Set 12 | vetralla
# Processing Record 26 of Set 12 | pampa
# Processing Record 27 of Set 12 | darab
# Processing Record 28 of Set 12 | bastogne
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | germersheim
# Processing Record 31 of Set 12 | rio tuba
# Processing Record 32 of Set 12 | moyale
# Processing Record 33 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | kirkwood
# Processing Record 35 of Set 12 | mount isa
# Processing Record 36 of Set 12 | acarau
# Processing Record 37 of Set 12 | sri aman
# Processing Record 38 of Set 12 | mahibadhoo
# Processing Record 39 of Set 12 | magadan
# Processing Record 40 of Set 12 | sisimiut
# Processing Record 41 of Set 12 | smithers
# Processing Record 42 of Set 12 | dauphin
# Processing Record 43 of Set 12 | pacasmayo
# Processing Record 44 of Set 12 | araouane
# Processing Record 45 of Set 12 | wageningen
# Processing Record 46 of Set 12 | locri
# Processing Record 47 of Set 12 | kholm-zhirkovskiy
# Processing Record 48 of Set 12 | rundu
# Processing Record 49 of Set 12 | sungai besar
# Processing Record 50 of Set 12 | praia da vitoria
# Processing Record 1 of Set 13 | worland
# Processing Record 2 of Set 13 | tizimin
# Processing Record 3 of Set 13 | rocha
# Processing Record 4 of Set 13 | abha
# Processing Record 5 of Set 13 | nichinan
# Processing Record 6 of Set 13 | maureni
# Processing Record 7 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 8 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 9 of Set 13 | nabire
# Processing Record 10 of Set 13 | raga
# Processing Record 11 of Set 13 | udomlya
# Processing Record 12 of Set 13 | spornoye
# Processing Record 13 of Set 13 | buluang
# Processing Record 14 of Set 13 | agirish
# Processing Record 15 of Set 13 | kalakamati
# Processing Record 16 of Set 13 | voyvozh
# Processing Record 17 of Set 13 | dodoma
# Processing Record 18 of Set 13 | yashkul
# Processing Record 19 of Set 13 | miri
# Processing Record 20 of Set 13 | gat
# Processing Record 21 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 13 | barguzin
# Processing Record 23 of Set 13 | ostrow mazowiecka
# Processing Record 24 of Set 13 | banamba
# Processing Record 25 of Set 13 | saint-pierre
# Processing Record 26 of Set 13 | trenggalek
# Processing Record 27 of Set 13 | burgos
# Processing Record 28 of Set 13 | barabai
# Processing Record 29 of Set 13 | lac du bonnet
# Processing Record 30 of Set 13 | gasa
# Processing Record 31 of Set 13 | ayan
# Processing Record 32 of Set 13 | male
# Processing Record 33 of Set 13 | panguna
# Processing Record 34 of Set 13 | teya
# Processing Record 35 of Set 13 | san jeronimo
# Processing Record 36 of Set 13 | hammerfest
# Processing Record 37 of Set 13 | suamico
# Processing Record 38 of Set 13 | stornoway
# Processing Record 39 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 13 | iquitos
# Processing Record 41 of Set 13 | sept-iles
# Processing Record 42 of Set 13 | chara
# Processing Record 43 of Set 13 | verkhnedneprovskiy
# Processing Record 44 of Set 13 | sterlibashevo
# Processing Record 45 of Set 13 | kemijarvi
# Processing Record 46 of Set 13 | ust-uda
# Processing Record 47 of Set 13 | grants pass
# Processing Record 48 of Set 13 | mareeba
# Processing Record 49 of Set 13 | wahpeton
# Processing Record 50 of Set 13 | menongue
# Processing Record 1 of Set 14 | lexington
# Processing Record 2 of Set 14 | coronado
# Processing Record 3 of Set 14 | bairiki
# Processing Record 4 of Set 14 | davila
# Processing Record 5 of Set 14 | ilam
# Processing Record 6 of Set 14 | puerto leguizamo
# Processing Record 7 of Set 14 | la rioja
# Processing Record 8 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 9 of Set 14 | crnomelj
# Processing Record 10 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 14 | seminole
# Processing Record 13 of Set 14 | north platte
# Processing Record 14 of Set 14 | haines junction
# Processing Record 15 of Set 14 | albania
# Processing Record 16 of Set 14 | nelson bay
# Processing Record 17 of Set 14 | dakar
# Processing Record 18 of Set 14 | bakel
# Processing Record 19 of Set 14 | wakkanai
# Processing Record 20 of Set 14 | camabatela
# Processing Record 21 of Set 14 | honningsvag
# Processing Record 22 of Set 14 | tokur
# Processing Record 23 of Set 14 | blackwater
# Processing Record 24 of Set 14 | comonfort
# Processing Record 25 of Set 14 | port hedland
# Processing Record 26 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 14 | benguela
# Processing Record 28 of Set 14 | terney
# Processing Record 29 of Set 14 | atlantic city
# Processing Record 30 of Set 14 | kiama
# Processing Record 31 of Set 14 | preobrazheniye
# Processing Record 32 of Set 14 | dzaoudzi
# Processing Record 33 of Set 14 | ponta delgada
# Processing Record 34 of Set 14 | fethiye
# Processing Record 35 of Set 14 | luwuk
# Processing Record 36 of Set 14 | anadyr
# Processing Record 37 of Set 14 | masindi
# Processing Record 38 of Set 14 | danli
# Processing Record 39 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | itoman
# Processing Record 41 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 14 | muli
# Processing Record 43 of Set 14 | saint anthony
# Processing Record 44 of Set 14 | islahiye
# Processing Record 45 of Set 14 | nueve de julio
# Processing Record 46 of Set 14 | masallatah
# Processing Record 47 of Set 14 | shumikha
# Processing Record 48 of Set 14 | kattivakkam
# Processing Record 49 of Set 14 | uruzgan
# Processing Record 50 of Set 14 | digby
# Processing Record 1 of Set 15 | drayton valley
# Processing Record 2 of Set 15 | garchitorena
# Processing Record 3 of Set 15 | dibulla
# Processing Record 4 of Set 15 | kushiro
# Processing Record 5 of Set 15 | hofn
# Processing Record 6 of Set 15 | matrei
# City not found. Skipping...
# Processing Record 7 of Set 15 | brigantine
# Processing Record 8 of Set 15 | sao filipe
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | baiyin
# Processing Record 11 of Set 15 | aksu
# Processing Record 12 of Set 15 | williams lake
# Processing Record 13 of Set 15 | kambove
# Processing Record 14 of Set 15 | sambava
# Processing Record 15 of Set 15 | aquin
# Processing Record 16 of Set 15 | saint-quentin
# Processing Record 17 of Set 15 | svolvaer
# Processing Record 18 of Set 15 | kirovo-chepetsk
# Processing Record 19 of Set 15 | boajibu
# Processing Record 20 of Set 15 | porto san giorgio
# Processing Record 21 of Set 15 | adre
# Processing Record 22 of Set 15 | marawi
# Processing Record 23 of Set 15 | estelle
# Processing Record 24 of Set 15 | catu
# Processing Record 25 of Set 15 | rio gallegos
# Processing Record 26 of Set 15 | gawler
# Processing Record 27 of Set 15 | namwala
# Processing Record 28 of Set 15 | kieta
# Processing Record 29 of Set 15 | farafangana
# Processing Record 30 of Set 15 | muros
# Processing Record 31 of Set 15 | havre-saint-pierre
# Processing Record 32 of Set 15 | saint-louis
# Processing Record 33 of Set 15 | wilmington island
# Processing Record 34 of Set 15 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 35 of Set 15 | baie-comeau
# Processing Record 36 of Set 15 | dovers
# Processing Record 37 of Set 15 | vallenar
# Processing Record 38 of Set 15 | novikovo
# Processing Record 39 of Set 15 | konya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Nikolskoye      RU  59.7035   30.7861     62.80        96
# 1              Bella Vista      US  36.4295  -94.2316     77.61        76
# 2              Provideniya      RU  64.3833 -173.3000     50.36        81
# 3                  Ushuaia      AR -54.8000  -68.3000     37.06        81
# 4                 Goderich      CA  43.7501  -81.7165     63.91        92
# 5            Mar Del Plata      AR -38.0023  -57.5575     45.09        70
# 6  San Carlos De Bariloche      AR -41.1456  -71.3082     33.55        75
# 7                     Sapa      PH   5.1544  120.3241     83.28        72
# 8                   Albany      US  42.6001  -73.9662     70.88        77
# 9          Bambous Virieux      MU -20.3428   57.7575     66.22        81
#
#    Cloudiness  Wind Speed      Current Description
# 0          15        5.66               few clouds
# 1           0        4.61                clear sky
# 2           0       11.18                clear sky
# 3          75        8.05  light intensity drizzle
# 4          50        8.37         scattered clouds
# 5           0       17.27                clear sky
# 6          75        6.91            broken clouds
# 7         100        4.52          overcast clouds
# 8          26        6.42         scattered clouds
# 9          91       14.63               light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
